# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod5-Statistics\datas
#
# 10/16/2023  11:49 AM    <DIR>          .
# 10/16/2023  11:49 AM    <DIR>          ..
# 10/16/2023  10:57 AM    <DIR>          .ipynb_checkpoints
# 08/21/2023  08:30 PM           322,026 airlines.csv
# 08/22/2023  09:08 AM               361 anagrams.csv
# 08/22/2023  09:09 AM               556 anscombe.csv
# 10/15/2023  12:31 PM    <DIR>          archive (10)
# 10/15/2023  12:33 PM    <DIR>          archive (13)
# 10/15/2023  12:28 PM    <DIR>          archive (2)
# 10/15/2023  12:30 PM    <DIR>          archive (3)
# 10/15/2023  12:30 PM    <DIR>          archive (4)
# 10/15/2023  12:30 PM    <DIR>          archive (5)
# 10/15/2023  12:30 PM    <DIR>          archive (6)
# 10/15/2023  12:30 PM    <DIR>          archive (7)
# 10/15/2023  12:30 PM    <DIR>          archive (8)
# 10/15/2023  12:30 PM    <DIR>          archive (9)
# ...

# %%
import numpy as np
import pandas as pd

# %%
Gdata = pd.read_csv("GlobalWeatherRepository.csv.xls",index_col="country")
Gdata
# Out:
#                 location_name  latitude  longitude         timezone  \
# country
# Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# Albania                Tirana     41.33      19.82    Europe/Tirane
# Algeria               Algiers     36.76       3.05   Africa/Algiers
# Andorra      Andorra La Vella     42.50       1.52   Europe/Andorra
# Angola                 Luanda     -8.84      13.23    Africa/Luanda
# ...                       ...       ...        ...              ...
# Venezuela             Caracas     10.50     -66.92  America/Caracas
# Vietnam                 Hanoi     21.03     105.85     Asia/Bangkok
# Yemen                   Sanaa     15.35      44.21        Asia/Aden
# Zambia                 Lusaka    -15.42      28.28    Africa/Lusaka
# Zimbabwe               Harare    -17.82      31.04    Africa/Harare
#
#              last_updated_epoch      last_updated  temperature_celsius  \
# country
# ...

# %%
Gdata.columns
# Out:
# Index(['location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
Gdata.shape
# Out:
# (9546, 40)

# %%
Gdata.size
# Out:
# 381840

# %%
Gdata["temperature_celsius"].mean()
# Out:
# 22.068258956631052

# %%
Gdata["temperature_celsius"].median()
# Out:
# 23.0

# %%
Gdata["temperature_celsius"].std()
# Out:
# 7.0472258804544525

# %%
temp_cel_var = Gdata["temperature_celsius"].var()
print("Variance of temperature_celsius",temp_cel_var)
# Out:
# Variance of temperature_celsius 49.66339261014703

# %%
humidity = Gdata["humidity"].var()
print("Variance of humidity",humidity)
# Out:
# Variance of humidity 418.1805776161226
